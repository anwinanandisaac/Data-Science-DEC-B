# %% [markdown]
# 1st of lets check our enivronment with a basic "hello world" Program

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# #import the required libraries.

# %%
import pandas as pd                                                      #FOR NUMPY
import numpy as np                                                       #FOR PANDAS
import matplotlib.pyplot as plt                                          #FOR PLOTTING
import statistics as stat                                                #FOR STSTISTICS (MEAN, MODE AND MEDIANS) IF REQUIRED
import seaborn as sns                                                    #FOR PLOTTING
from sklearn.preprocessing import LabelEncoder                           #For encoding catergoircal values object data
from sklearn.preprocessing import StandardScaler                         #FOR STANDARD SCALING
from sklearn.preprocessing import MinMaxScaler                           #FOR MIN-MAX SCALEING
from sklearn.model_selection import train_test_split                      #FOR TRAIN TEST SPLIT
from sklearn.linear_model import LogisticRegression                      #FOR LOGISTIC REGRESSION

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# Importing the required dataset into our colab environment.

# %%
data = pd.read_csv('/content/Employee.csv')

# %% [markdown]
# lets analyze the dataset using head() and tail() functions

# %%
data.head() # checking the rows data of first 5 rows
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
# ...

# %%
data.tail() # checking the rows data of last 5 rows
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 74493        16243   56  Female                42  Healthcare            7830
# 74494        47175   30  Female                15   Education            3856
# 74495        12409   52    Male                 5   Education            5654
# 74496         9554   18    Male                 4   Education            5276
# 74497        73042   59  Female                48   Education            3774
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 74493              Poor           Medium            Average
# 74494              Good           Medium            Average
# 74495              Good        Very High      Below Average
# 74496              Fair             High            Average
# 74497              Good             High      Below Average
#
#        Number of Promotions  ... Number of Dependents  Job Level Company Size  \
# ...

# %% [markdown]
# #Taking info function

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74498 entries, 0 to 74497
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               74498 non-null  int64
#  1   Age                       74498 non-null  int64
#  2   Gender                    74498 non-null  object
#  3   Years at Company          74498 non-null  int64
#  4   Job Role                  74498 non-null  object
#  5   Monthly Income            74498 non-null  int64
#  6   Work-Life Balance         74494 non-null  object
#  7   Job Satisfaction          74498 non-null  object
#  8   Performance Rating        74494 non-null  object
#  9   Number of Promotions      74493 non-null  float64
#  10  Overtime                  74498 non-null  object
#  11  Distance from Home        74498 non-null  int64
#  12  Education Level           74493 non-null  object
# ...

# %%
data.describe()      #FUNCTION TO INVOKE COUNT,MEAN,STANDARD DEVIATION,MIN AND MAX VALUES collectivelly called as statistical data analysis
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  74498.000000  74498.000000      74498.000000    74498.000000
# mean   37249.500000     38.529746         15.721603     7299.379514
# std    21505.864514     12.083456         11.223744     2152.508566
# min        1.000000     18.000000          1.000000     1226.000000
# 25%    18625.250000     28.000000          7.000000     5652.000000
# 50%    37249.500000     39.000000         13.000000     7348.000000
# 75%    55873.750000     49.000000         23.000000     8876.000000
# max    74498.000000     59.000000         51.000000    16149.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          74493.000000        74498.000000          74492.000000
# mean               0.832978           49.991584              1.650365
# std                0.995303           28.513611              1.553660
# min                0.000000            1.000000              0.000000
# ...

# %%
data.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure',
#        'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')

# %% [markdown]
# #checking for data number of unique values in "gender" and "Attrition"

# %%
data['Gender'].nunique()
# Out:
# 2

# %%
data['Attrition'].nunique()
# Out:
# 2

# %% [markdown]
# #since Employee ID has all unique values lets drop it all together.

# %%
data.drop('Employee ID',axis=1,inplace=True)

# %% [markdown]
# #now use information function

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74498 entries, 0 to 74497
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       74498 non-null  int64
#  1   Gender                    74498 non-null  object
#  2   Years at Company          74498 non-null  int64
#  3   Job Role                  74498 non-null  object
#  4   Monthly Income            74498 non-null  int64
#  5   Work-Life Balance         74494 non-null  object
#  6   Job Satisfaction          74498 non-null  object
#  7   Performance Rating        74494 non-null  object
#  8   Number of Promotions      74493 non-null  float64
#  9   Overtime                  74498 non-null  object
#  10  Distance from Home        74498 non-null  int64
#  11  Education Level           74493 non-null  object
#  12  Marital Status            74494 non-null  object
# ...

# %% [markdown]
# #check for null values

# %%
data.isna().sum()    #function to invoke sum of null values in each columns
# Out:
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           4
# Job Satisfaction            0
# Performance Rating          4
# Number of Promotions        5
# Overtime                    0
# Distance from Home          0
# Education Level             5
# Marital Status              4
# Number of Dependents        6
# Job Level                   5
# Company Size                2
# Company Tenure              0
# Remote Work                 3
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        2
# Attrition                   0
# dtype: int64

# %% [markdown]
# #we need to rename the columns

# %%
data = data.rename(columns={'Years at Company':"Years_at_Company"})
data = data.rename(columns={'Job Role':"Job_Role"})
data = data.rename(columns={'Monthly Income':"Monthly_Income"})
data = data.rename(columns={'Work-Life Balance':"Work-Life_Balance"})

data = data.rename(columns={'Job Satisfaction':"Job_Satisfaction"})
data = data.rename(columns={'Performance Rating':"Performance_Rating"})
data = data.rename(columns={'Number of Promotions':"Number_of_Promotions"})
data = data.rename(columns={'Distance from Home':"Distance_from_Home"})

data = data.rename(columns={'Education Level':"Education_Level"})
data = data.rename(columns={'Marital Status':"Marital_Status"})
data = data.rename(columns={'Number of Dependents':"Number_of_Dependents"})
data = data.rename(columns={'Job Level':"Job_Level"})

data = data.rename(columns={'Company Size':"Company_Size"})
data = data.rename(columns={'Company Tenure':"Company_Tenure"})
data = data.rename(columns={'Remote Work':"Remote_Work"})
data = data.rename(columns={'Leadership Opportunities':"Leadership_Opportunities"})

data = data.rename(columns={'Innovation Opportunities':"Innovation_Opportunities"})
data = data.rename(columns={'Company Reputation':"Company_Reputation"})


data = data.rename(columns={'Employee Recognition':"Employee_Recognition"})

# %% [markdown]
# Since there are missing values we need fill them. Object or categorical data are filled using mode. Float and int values are filled on the basis of skewness.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74498 entries, 0 to 74497
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       74498 non-null  int64
#  1   Gender                    74498 non-null  object
#  2   Years_at_Company          74498 non-null  int64
#  3   Job_Role                  74498 non-null  object
#  4   Monthly_Income            74498 non-null  int64
#  5   Work-Life_Balance         74494 non-null  object
#  6   Job_Satisfaction          74498 non-null  object
#  7   Performance_Rating        74494 non-null  object
#  8   Number_of_Promotions      74493 non-null  float64
#  9   Overtime                  74498 non-null  object
#  10  Distance_from_Home        74498 non-null  int64
#  11  Education_Level           74493 non-null  object
#  12  Marital_Status            74494 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Years_at_Company', 'Job_Role', 'Monthly_Income',
#        'Work-Life_Balance', 'Job_Satisfaction', 'Performance_Rating',
#        'Number_of_Promotions', 'Overtime', 'Distance_from_Home',
#        'Education_Level', 'Marital_Status', 'Number_of_Dependents',
#        'Job_Level', 'Company_Size', 'Company_Tenure', 'Remote_Work',
#        'Leadership_Opportunities', 'Innovation_Opportunities',
#        'Company_Reputation', 'Employee_Recognition', 'Attrition'],
#       dtype='object')

# %%
data.Number_of_Dependents.skew()
# Out:
# 0.7070916759977594

# %%
plt.hist(data['Number_of_Dependents'])                            #FILL NULLVALUES WITH MEDIAN METHOD SINCE HIGHLY SKEWED
plt.show()

# %% [markdown]
# # **the chart shows skewed data hence median.**

# %%
data.Company_Tenure.skew()
# Out:
# 0.06566968712522454

# %%
plt.hist(data['Company_Tenure'])                            #FILL NULLVALUES WITH MEDIAN METHOD SINCE HIGHLY SKEWED
plt.show()

# %% [markdown]
# #the data is bell shaped hencee we can fill it by mean or median method. i take mean().

# %%
data['Number_of_Dependents'].fillna(data['Number_of_Dependents'].median(), inplace=True)
data['Company_Tenure'].fillna(data['Company_Tenure'].mean(), inplace=True)
data['Number_of_Promotions'].fillna(data['Number_of_Promotions'].median(), inplace=True)

# %% [markdown]
# # Now moving to filling of object dtypes using mode or highest frequency method.

# %%
object_columns = data.select_dtypes(include=['object']).columns
for col in object_columns:
  mode_value = data[col].mode()[0]
  data[col].fillna(data[col].mode()[0], inplace=True)

# %% [markdown]
# Mode values are fill inside all columns using a for loop.

# %% [markdown]
# #now check again for the null values again and check it

# %%
data.isna().sum()    #function to invoke sum of null values in each columns
# Out:
# Age                         0
# Gender                      0
# Years_at_Company            0
# Job_Role                    0
# Monthly_Income              0
# Work-Life_Balance           0
# Job_Satisfaction            0
# Performance_Rating          0
# Number_of_Promotions        0
# Overtime                    0
# Distance_from_Home          0
# Education_Level             0
# Marital_Status              0
# Number_of_Dependents        0
# Job_Level                   0
# Company_Size                0
# Company_Tenure              0
# Remote_Work                 0
# Leadership_Opportunities    0
# Innovation_Opportunities    0
# Company_Reputation          0
# Employee_Recognition        0
# Attrition                   0
# dtype: int64

# %% [markdown]
# #the null values are removed.

# %% [markdown]
# # 2. Now the outliers needs to be check to be clipped for numerical values.

# %% [markdown]
# Before that we can plot graphs based on numerical values using freqgraph

# %%
freqgraph = data.select_dtypes(include=['float64', 'int64'])

# %%
freqgraph.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# #The above graphs thus shows us that all the features skewness are high. Thus we can go for IQR or interquartile range tests instead of Z_score test. we come to this conclusion that there are no bell shaped or normally distributed curves

# %% [markdown]
# Performing IQR test:- checking for outliers and clipping them off.

# %%
data.head()
# Out:
#    Age  Gender  Years_at_Company    Job_Role  Monthly_Income  \
# 0   31    Male                19   Education            5390
# 1   59  Female                 4       Media            5534
# 2   24  Female                10  Healthcare            8159
# 3   36  Female                 7   Education            3989
# 4   56    Male                41   Education            4821
#
#   Work-Life_Balance Job_Satisfaction Performance_Rating  Number_of_Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
#   Overtime  ...  Number_of_Dependents Job_Level Company_Size  Company_Tenure  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74498 entries, 0 to 74497
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       74498 non-null  int64
#  1   Gender                    74498 non-null  object
#  2   Years_at_Company          74498 non-null  int64
#  3   Job_Role                  74498 non-null  object
#  4   Monthly_Income            74498 non-null  int64
#  5   Work-Life_Balance         74498 non-null  object
#  6   Job_Satisfaction          74498 non-null  object
#  7   Performance_Rating        74498 non-null  object
#  8   Number_of_Promotions      74498 non-null  float64
#  9   Overtime                  74498 non-null  object
#  10  Distance_from_Home        74498 non-null  int64
#  11  Education_Level           74498 non-null  object
#  12  Marital_Status            74498 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Years_at_Company', 'Job_Role', 'Monthly_Income',
#        'Work-Life_Balance', 'Job_Satisfaction', 'Performance_Rating',
#        'Number_of_Promotions', 'Overtime', 'Distance_from_Home',
#        'Education_Level', 'Marital_Status', 'Number_of_Dependents',
#        'Job_Level', 'Company_Size', 'Company_Tenure', 'Remote_Work',
#        'Leadership_Opportunities', 'Innovation_Opportunities',
#        'Company_Reputation', 'Employee_Recognition', 'Attrition'],
#       dtype='object')

# %%
new_columns_out = ['Age','Years_at_Company','Monthly_Income','Number_of_Promotions','Distance_from_Home','Number_of_Dependents','Company_Tenure']
#SELECTING numerical COLUMNS THAT NEEDS TO BE OUTLIER DETECTED AT ONCE USING A FOR LOOP

# %%
for i in new_columns_out:
  plt.figure(i)
  plt.boxplot(data[i])
  plt.title(i);

# %% [markdown]
# # So we find that there are outliers in our data. **So we do data cleaning under data preprocessing to clip the outliers.**

# %%
#outlier clipping is done by

for j in ['Age','Years_at_Company','Monthly_Income','Number_of_Promotions','Distance_from_Home','Number_of_Dependents','Company_Tenure']:
    Q1=np.percentile(data[j],25,method='midpoint')
    Q2=np.percentile(data[j],50,method='midpoint')
    Q3=np.percentile(data[j],75,method='midpoint')
    IQR = Q3-Q1
    low_lim = Q1-1.5*IQR
    up_lim = Q3+1.5*IQR
    outliers = []
    for h in data[j]:
        if ((h < low_lim) | (h > up_lim)):
            outliers.append(h)
    data[j]=data[j].clip(lower=low_lim,upper=up_lim)

# %% [markdown]
# The code for clipping outliers were exceuted now we need to check whether the outliers are actually clipped off.

# %%
new_columns_out_final = ['Age','Years_at_Company','Monthly_Income','Number_of_Promotions','Distance_from_Home','Number_of_Dependents','Company_Tenure']

# %%
for z in new_columns_out_final:
  plt.figure(z)
  plt.boxplot(data[z])
  plt.title(z);

# %% [markdown]
# **#THUS THE OUTLIERS ARE CLIPPED SUCCESSFULLY.**

# %% [markdown]
# #Now the next step in pre processing is to do Encoding(changing object/catergorical values ) into machine format for better ML algorithums. Then scaling (Standard scaling). If scaling is not done ML algoritum tends to weigh greater values.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data.dtypes
# Out:
# Age                           int64
# Gender                       object
# Years_at_Company              int64
# Job_Role                     object
# Monthly_Income                int64
# Work-Life_Balance            object
# Job_Satisfaction             object
# Performance_Rating           object
# Number_of_Promotions        float64
# Overtime                     object
# Distance_from_Home            int64
# Education_Level              object
# Marital_Status               object
# Number_of_Dependents        float64
# Job_Level                    object
# Company_Size                 object
# Company_Tenure                int64
# Remote_Work                  object
# Leadership_Opportunities     object
# Innovation_Opportunities     object
# Company_Reputation           object
# Employee_Recognition         object
# Attrition                    object
# dtype: object

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Years_at_Company', 'Job_Role', 'Monthly_Income',
#        'Work-Life_Balance', 'Job_Satisfaction', 'Performance_Rating',
#        'Number_of_Promotions', 'Overtime', 'Distance_from_Home',
#        'Education_Level', 'Marital_Status', 'Number_of_Dependents',
#        'Job_Level', 'Company_Size', 'Company_Tenure', 'Remote_Work',
#        'Leadership_Opportunities', 'Innovation_Opportunities',
#        'Company_Reputation', 'Employee_Recognition', 'Attrition'],
#       dtype='object')

# %% [markdown]
# lets do label encoding as a **for loop** since it will be easy.

# %%
cat_col = ['Gender','Job_Role','Work-Life_Balance','Job_Satisfaction','Performance_Rating','Overtime','Education_Level','Marital_Status','Job_Level','Company_Size','Remote_Work','Leadership_Opportunities','Innovation_Opportunities','Company_Reputation', 'Employee_Recognition', 'Attrition']

# %%
for column in cat_col:
    data[column] = le.fit_transform(data[column])

# %% [markdown]
# DATA IS SUCCESSFULLY ENCODED and 1st 5 rows and last 5 rows are shown as proof of work.

# %%
data.head()
# Out:
#    Age  Gender  Years_at_Company  Job_Role  Monthly_Income  Work-Life_Balance  \
# 0   31       1                19         0            5390                  0
# 1   59       0                 4         3            5534                  3
# 2   24       0                10         2            8159                  2
# 3   36       0                 7         0            3989                  2
# 4   56       1                41         0            4821                  1
#
#    Job_Satisfaction  Performance_Rating  Number_of_Promotions  Overtime  ...  \
# 0                 2                   0                   2.0         0  ...
# 1                 0                   3                   3.0         0  ...
# 2                 0                   3                   0.0         0  ...
# 3                 0                   2                   1.0         0  ...
# 4                 3                   0                   0.0         1  ...
#
# ...

# %%
data.tail()
# Out:
#        Age  Gender  Years_at_Company  Job_Role  Monthly_Income  \
# 74493   56       0                42         2            7830
# 74494   30       0                15         0            3856
# 74495   52       1                 5         0            5654
# 74496   18       1                 4         0            5276
# 74497   59       0                47         0            3774
#
#        Work-Life_Balance  Job_Satisfaction  Performance_Rating  \
# 74493                  3                 2                   0
# 74494                  2                 2                   0
# 74495                  2                 3                   1
# 74496                  1                 0                   0
# 74497                  2                 0                   1
#
#        Number_of_Promotions  Overtime  ...  Number_of_Dependents  Job_Level  \
# 74493                   0.0         1  ...                   0.0          2
# ...

# %% [markdown]
# Lets do a correlation between the variables

# %%
data.corr()
# Out:
#                                Age    Gender  Years_at_Company  Job_Role  \
# Age                       1.000000 -0.003467          0.537264  0.000004
# Gender                   -0.003467  1.000000         -0.001610 -0.010268
# Years_at_Company          0.537264 -0.001610          1.000000 -0.000115
# Job_Role                  0.000004 -0.010268         -0.000115  1.000000
# Monthly_Income           -0.001758 -0.000814         -0.005948  0.549120
# Work-Life_Balance        -0.004367 -0.004488         -0.002247 -0.003445
# Job_Satisfaction          0.001663  0.002131         -0.000038  0.002468
# Performance_Rating       -0.000039 -0.006692         -0.001693 -0.000936
# Number_of_Promotions      0.000656 -0.001453          0.000976 -0.000684
# Overtime                 -0.000451 -0.000013         -0.002262  0.005853
# Distance_from_Home       -0.004586 -0.002077         -0.004799 -0.001118
# Education_Level           0.005050 -0.003121          0.005257 -0.004927
# ...

# %%
sns.heatmap(data.corr(),cmap='YlGnBu',annot=True)      #DISPLAYING THEM IN HEATMAPS
# Out:
# <Axes: >

# %%
import seaborn as sns
plt.figure(figsize=(24,20))
cmap = sns.diverging_palette(220, 10, center='light', as_cmap=True)
sns.heatmap(data = data.corr(),annot=True,cmap=cmap)
# Out:
# <Axes: >

# %% [markdown]
# There isnt any highly poistive or negatively correlated values as glancing through the correlation chart. Thus no features can be dropped.

# %% [markdown]
# # Now lets do train_test_split_test and do scaling inside it.

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Years_at_Company', 'Job_Role', 'Monthly_Income',
#        'Work-Life_Balance', 'Job_Satisfaction', 'Performance_Rating',
#        'Number_of_Promotions', 'Overtime', 'Distance_from_Home',
#        'Education_Level', 'Marital_Status', 'Number_of_Dependents',
#        'Job_Level', 'Company_Size', 'Company_Tenure', 'Remote_Work',
#        'Leadership_Opportunities', 'Innovation_Opportunities',
#        'Company_Reputation', 'Employee_Recognition', 'Attrition'],
#       dtype='object')

# %% [markdown]
# It is very evident that this is a classification based model. So we assign the dependent variable to y(Attrition) and all other indepentent variables to X. Dependent variable is also called target variable.

# %%
y = data.Attrition
X = data.drop('Attrition',axis=1)

# %%
X.isna().sum()
# Out:
# Age                         0
# Gender                      0
# Years_at_Company            0
# Job_Role                    0
# Monthly_Income              0
# Work-Life_Balance           0
# Job_Satisfaction            0
# Performance_Rating          0
# Number_of_Promotions        0
# Overtime                    0
# Distance_from_Home          0
# Education_Level             0
# Marital_Status              0
# Number_of_Dependents        0
# Job_Level                   0
# Company_Size                0
# Company_Tenure              0
# Remote_Work                 0
# Leadership_Opportunities    0
# Innovation_Opportunities    0
# Company_Reputation          0
# Employee_Recognition        0
# dtype: int64

# %%
from sklearn.metrics import accuracy_score,confusion_matrix, precision_score, recall_score, f1_score

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %% [markdown]
# #Performing standard scaling to reduce the burden on the system due to high data weightage and also give prefference to lower data like age in terms of high values like Monthly Income.

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %% [markdown]
# #1.**Logistic** Regression

# %%
from sklearn.linear_model import LogisticRegression
logistic_reg = LogisticRegression()
logistic_reg.fit(X_train, y_train)
logistic_reg_pred = logistic_reg.predict(X_test)
logistic_reg_accuracy = accuracy_score(y_test, logistic_reg_pred)
logistic_precision = precision_score(y_test, logistic_reg_pred, average='macro')
logistic_recall = recall_score(y_test, logistic_reg_pred, average='macro')
logistic_f1 = f1_score(y_test, logistic_reg_pred, average='macro')
print("logistic_reg_accuracy:", logistic_reg_accuracy)
print("confusion_matrix:", confusion_matrix(y_test,logistic_reg_pred))
print("precision_score:",logistic_precision)
print("recall_score:",logistic_recall)
print("f1_score:",logistic_f1)
# Out:
# logistic_reg_accuracy: 0.7223489932885906
# confusion_matrix: [[4999 2097]
#  [2040 5764]]
# precision_score: 0.7217130758883318
# recall_score: 0.7215384949873941
# f1_score: 0.7216151625309318

# %% [markdown]
# #2. DECISION TREE CLASSIFICATION

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, y_train)
decision_tree_pred = decision_tree.predict(X_test)
decision_tree_accuracy = accuracy_score(y_test, decision_tree_pred)
decision_tree_precision = precision_score(y_test, decision_tree_pred, average='macro')
decision_tree_recall = recall_score(y_test, decision_tree_pred, average='macro')
decision_tree_f1 = f1_score(y_test, decision_tree_pred, average='macro')
print("Decision Tree Accuracy:", decision_tree_accuracy)
print("confusion_matrix:", confusion_matrix(y_test,decision_tree_pred))
print("precision_score:",decision_tree_precision)
print("recall_score:",decision_tree_recall)
print("f1_score:",decision_tree_f1)
# Out:
# Decision Tree Accuracy: 0.6731543624161074
# confusion_matrix: [[4659 2437]
#  [2433 5371]]
# precision_score: 0.6724108077792572
# recall_score: 0.6724019408426402
# f1_score: 0.672406325626496

# %% [markdown]
# #3.#  RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier()
random_forest.fit(X_train, y_train)
random_forest_pred = random_forest.predict(X_test)
random_forest_accuracy = accuracy_score(y_test, random_forest_pred)
random_forest_precision = precision_score(y_test, random_forest_pred, average='macro')
random_forest_recall = recall_score(y_test, random_forest_pred, average='macro')
random_forest_f1 = f1_score(y_test, random_forest_pred, average='macro')
print("Random Forest Accuracy:", random_forest_accuracy)
print("confusion_matrix:", confusion_matrix(y_test,random_forest_pred))
print("precision_score:",random_forest_precision)
print("recall_score:",random_forest_recall)
print("f1_score:",random_forest_f1)
# Out:
# Random Forest Accuracy: 0.7498657718120806
# confusion_matrix: [[5244 1852]
#  [1875 5929]]
# precision_score: 0.7493023163114707
# recall_score: 0.7493732436810077
# f1_score: 0.7493359856667469

# %% [markdown]
# **FINE Tunning RANDOM FOREST CLASSIFIER** AS I TOOK THE SELECTED CLASSIFICATION MODEL AS RANDOM FOREST.

# %% [markdown]
# #6.HYPER-TUNNING PARAMETER

# %%
rf_clf = RandomForestClassifier(n_estimators=20,max_depth=20,criterion='entropy',min_samples_split=2)
rf_clf.fit(X_train,y_train)
y_pred = rf_clf.predict(X_test)
print('confusion_matrix',confusion_matrix(y_test,y_pred))
print('Accuracy',accuracy_score(y_test,y_pred))
print("precision_score:",precision_score(y_test,y_pred, average='macro'))
print("recall_score:",recall_score(y_test,y_pred, average='macro'))
print("f1_score:",f1_score(y_test,y_pred, average='macro'))
# Out:
# confusion_matrix [[5139 1957]
#  [1879 5925]]
# Accuracy 0.7425503355704698
# precision_score: 0.7419863331821772
# recall_score: 0.7417184304640698
# f1_score: 0.7418319210553593

# %% [markdown]
# #5.k-nn

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
knn_pred = knn.predict(X_test)
knn_accuracy = accuracy_score(y_test, knn_pred)
knn_precision = precision_score(y_test, knn_pred, average='macro')
knn_recall = recall_score(y_test, knn_pred, average='macro')
knn_f1 = f1_score(y_test, knn_pred, average='macro')
print("KNN Accuracy:", knn_accuracy)
print("confusion_matrix:", confusion_matrix(y_test,knn_pred))
print("precision_score:",knn_precision)
print("recall_score:",knn_recall)
print("f1_score:",knn_f1)
# Out:
# KNN Accuracy: 0.6741610738255034
# confusion_matrix: [[4610 2486]
#  [2369 5435]]
# precision_score: 0.6733519131890233
# recall_score: 0.6730497527646042
# f1_score: 0.6731590644034484

# %% [markdown]
# SVC(SVM)

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train)
svm_pred = svm.predict(X_test)
svm_accuracy = accuracy_score(y_test, svm_pred)
svm_precision = precision_score(y_test, svm_pred, average='macro')
svm_recall = recall_score(y_test, svm_pred, average='macro')
svm_f1 = f1_score(y_test, svm_pred, average='macro')
print("SVM Accuracy:", svm_accuracy)
print("confusion_matrix:", confusion_matrix(y_test,svm_pred))
print("precision_score:",svm_precision)
print("recall_score:",svm_recall)
print("f1_score:",svm_f1)

# %% [markdown]
# i DIDNT GET THE VALUE FOR sVM/SVC ML MODEL.

# %% [markdown]
# **#THANK YOU**
