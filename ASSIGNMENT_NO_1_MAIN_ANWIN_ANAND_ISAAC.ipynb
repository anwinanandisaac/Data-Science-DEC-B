# %% [markdown]
# # **Assignment #01 - NumPy, Pandas, Matplotlib and Seaborn**

# %%
#Assignment on Python for Data Science
#Do the following operation on Iris dataset:
#1. Read the dataset to python environment.
#2. Display the columns in the dataset.
#3. Calculate the mean of each column of the dataset.
#4. Check for the null values present in the dataset.
#5. Perform meaningful visualizations using the dataset. Bring at least 3
#visualizations.

# %%
#IMPORTING VARIOUS LIBRARIES TO COLAB WORKSPACE
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #QUESTION 1.:- READ THE DATASET TO PYTHON ENVIRONMENT.

# %%
#NOW WE HAVE TO UPLOAD THE GIVEN EXCEL FILE INTO COLAB
#IT IS DONE AS FOLLOWS AND THE DATA VARIABLE IS CALLED UPON TO VIEW THE FILE ON COLAB
data = pd.read_excel('/content/iris.xls')           #SYNTAX: variable = pd.read_file_type('copy link/path)
data                                                #calling data variable
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#NOW LETS CALL THE FIRST 5 ROWS AND LAST 5 ROWS OF THE OUR DATA PROVIDED TO EXAMINE THE BASIC NATURE OF DATA PRESENTEED TO US
data.head()       #DISPLAYING 1ST 5 ROWS OF DATA
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data.tail()         #DISPLAYING LAST 5 ROWS
# Out:
#       SL   SW   PL   PW  Classification
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
 #TO GET THE INFORMATION(INFO.) OF THE DATA SUCHAS DATA, COLUMNS, NON_NULL COUNT AND DATATYPE
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#NOW LETS CHECK THE SHAPE i.e. THE NUMBER OF ROWS AND COLUMNS
data.shape
# Out:
# (150, 5)

# %% [markdown]
# # QUESTION 2.: DISPLAY THE COLUMNS IN THE DATASET.

# %%
# TO Display the columns in the dataset.
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
data #calling the dataset stored variable
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # QUESTION 3.: CALCULATE THE MEAN OF EACH COLUMNS OF THE DATASET

# %%
#TO DISPLAY AND CALCUATE THE MEAN OF EACH COLUMN WE CAN USE THE DESCRIBE FUNCTION
data.describe()     #ALONG WITH MEAN IT SHOWS COUNT VALUE, STANDARD DEVIATION, MIN/MAX VALUES,25%,50% AND 75% VALUES:
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#TO DISPLAY THE MEAN ONLY, WE CAN INPUT THE MEAN FUNCTION WHICH RETURNS THE MEAN OF ALL COLUMNS
data.mean()
# Out:
# <ipython-input-38-48ec2766f229>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # QUESTION 4.: CHECK FOR THE NULL VALUES PRESENT IN THE DATASET.

# %%
#TO GET THE INFORMATION(INFO.) OF THE DATA SUCHAS DATA, COLUMNS, NON_NULL COUNT AND DATATYPE
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#TO FIND OUT WHETHER THE VALUES PRESENT IN THE DATASET IS NULL OR NOT isna() function is used.
#IT GIVES BACK A BOOLEN DATA AS TRUE IF THE ELEMENT IS NULL OR FALSE IF THE DATA IS NOT NULL.
data.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
#THE FOLLOWING FUNCTION IS USED TO DISPLAY DATA OF/WITH NULL VALUES
data[data.isna()]
# Out:
#      SL  SW  PL  PW Classification
# 0   NaN NaN NaN NaN            NaN
# 1   NaN NaN NaN NaN            NaN
# 2   NaN NaN NaN NaN            NaN
# 3   NaN NaN NaN NaN            NaN
# 4   NaN NaN NaN NaN            NaN
# ..   ..  ..  ..  ..            ...
# 145 NaN NaN NaN NaN            NaN
# 146 NaN NaN NaN NaN            NaN
# 147 NaN NaN NaN NaN            NaN
# 148 NaN NaN NaN NaN            NaN
# 149 NaN NaN NaN NaN            NaN
#
# [150 rows x 5 columns]

# %%
#THE FOLLOWING FUNCTION IS USED TO DISPLAY NON-NULL DATASETS:
data.notnull()
# Out:
#        SL    SW    PL    PW  Classification
# 0    True  True  True  True            True
# 1    True  True  True  True            True
# 2    True  True  True  True            True
# 3    True  True  True  True            True
# 4    True  True  True  True            True
# ..    ...   ...   ...   ...             ...
# 145  True  True  True  True            True
# 146  True  True  True  True            True
# 147  True  True  True  True            True
# 148  True  True  True  True            True
# 149  True  True  True  True            True
#
# [150 rows x 5 columns]

# %%
#THE FOLLOWING FUNCTION IS SIMILAR TO isna() function displays boolyen value false if not null and true if its null.
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
#THE FOLLOWING FUCTION IS USED TO DISPLAY DATAS OF DATASET WHICH ARE NOT NULL VALUES.
data[data.notna()]
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#TO CHECK WHETHER HOW MANY NUMBER OF NULL CHARACTERS IN A DATASET THE FOLLOWING FUNCTION IS USED:
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # QUESTION 5.: PERFORM MEANINGFUL VISUALIZATIONS USING THE DATASET.

# %%
# Scatter plot using matplotlib: GRAPH PLOTTED PW(PETAL WIDTH) ALONG Y-AXIS vs PL(PETAL LENGTH) ALONG X-AXIS
#                           ONE OUT OF THREE:
plt.scatter(data.PL,data.PW)         #SYNTAX FOR SCATTERPLOTTING
plt.xlabel('PL(petal length)')       #NAMING THE X-AXIS
plt.ylabel('PW(petal width)')        #NAMING THE Y-AXIS
plt.title('GRAPH BETWEEN PL vs PW')  #NAMING THE TITLE
# Out:
# Text(0.5, 1.0, 'GRAPH BETWEEN PL vs PW')

# %%
# Histogram using seaborn: THE BELOW GRAPH REPRESENTS HOW MANY OF THE PETALS OF THE GIVEN DATA ARE SAME/IDENTICAL:
#              TWO OUT OF THREE

sns.histplot(x=data.PL,color='black')
# Out:
# <Axes: xlabel='PL', ylabel='Count'>

# %%
# Scatter plot using matplotlib: GRAPH PLOTTED PW(PETAL WIDTH) ALONG Y-AXIS vs PL(PETAL LENGTH) ALONG X-AXIS
#                           ONE OUT OF THREE:
plt.scatter(data.PL,data.SL)         #SYNTAX FOR SCATTERPLOTTING
plt.xlabel('PL(petal length)')       #NAMING THE X-AXIS
plt.ylabel('SL(sepel length)')        #NAMING THE Y-AXIS
plt.title('GRAPH BETWEEN PW vs SL')  #NAMING THE TITLE
# Out:
# Text(0.5, 1.0, 'GRAPH BETWEEN PW vs SL')
